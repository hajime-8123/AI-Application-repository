# %% [markdown]
# <a href="https://colab.research.google.com/github/hajime-8123/AI-Application-repository/blob/main/W6_AI_Application_Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
train_labels, test_labels = to_categorical(train_labels), to_categorical(test_labels)

# Create a CNN model with Dropout and Batch Normalization
model = models.Sequential()

# Convolutional Layer 1 with Batch Normalization and MaxPooling
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Convolutional Layer 2 with Batch Normalization and MaxPooling
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Convolutional Layer 3 with Batch Normalization and GlobalAveragePooling
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.GlobalAveragePooling2D())

# Fully connected layers with Dropout
model.add(layers.Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

# Output layer
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_images, train_labels, epochs=10, batch_size=64, validation_data=(test_images, test_labels))

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_accuracy * 100:.2f}%')
# Out:
# ...
# 170498071/170498071 [==============================] - 2s 0us/step
# Epoch 1/10
# 782/782 [==============================] - 54s 67ms/step - loss: 1.6963 - accuracy: 0.4171 - val_loss: 1.7351 - val_accuracy: 0.4120
# Epoch 2/10
# 782/782 [==============================] - 56s 71ms/step - loss: 1.2313 - accuracy: 0.5633 - val_loss: 1.4477 - val_accuracy: 0.5357
# Epoch 3/10
# 782/782 [==============================] - 52s 67ms/step - loss: 1.0788 - accuracy: 0.6235 - val_loss: 1.0050 - val_accuracy: 0.6367
# Epoch 4/10
# 782/782 [==============================] - 53s 68ms/step - loss: 0.9984 - accuracy: 0.6504 - val_loss: 1.6343 - val_accuracy: 0.5050
# Epoch 5/10
# 782/782 [==============================] - 53s 67ms/step - loss: 0.9259 - accuracy: 0.6753 - val_loss: 1.2603 - val_accuracy: 0.5835
# Epoch 6/10
# 782/782 [==============================] - 53s 67ms/step - loss: 0.8767 - accuracy: 0.6972 - val_loss: 0.8481 - val_accuracy: 0.7016
# Epoch 7/10
# ...

# %%
# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
train_labels, test_labels = to_categorical(train_labels), to_categorical(test_labels)

# Create a CNN model with different activation functions
model = models.Sequential()

# Convolutional Layer 1 with Tanh activation
model.add(layers.Conv2D(32, (3, 3), activation='tanh', input_shape=(32, 32, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Convolutional Layer 2 with PReLU activation
model.add(layers.Conv2D(64, (3, 3)))
model.add(layers.PReLU())
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Convolutional Layer 3 with ELU activation
model.add(layers.Conv2D(128, (3, 3), activation='elu'))
model.add(layers.BatchNormalization())
model.add(layers.GlobalAveragePooling2D())

# Fully connected layers with Tanh activation
model.add(layers.Dense(128, activation='tanh'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

# Output layer with softmax activation
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_images, train_labels, epochs=10, batch_size=64, validation_data=(test_images, test_labels))

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Epoch 1/10
# 782/782 [==============================] - 60s 75ms/step - loss: 1.6756 - accuracy: 0.4244 - val_loss: 1.6769 - val_accuracy: 0.3967
# Epoch 2/10
# 782/782 [==============================] - 57s 72ms/step - loss: 1.1628 - accuracy: 0.5912 - val_loss: 1.1611 - val_accuracy: 0.5909
# Epoch 3/10
# 782/782 [==============================] - 57s 73ms/step - loss: 1.0158 - accuracy: 0.6461 - val_loss: 0.9557 - val_accuracy: 0.6712
# Epoch 4/10
# 782/782 [==============================] - 57s 73ms/step - loss: 0.9215 - accuracy: 0.6806 - val_loss: 0.9682 - val_accuracy: 0.6595
# Epoch 5/10
# 782/782 [==============================] - 57s 73ms/step - loss: 0.8567 - accuracy: 0.7026 - val_loss: 0.8725 - val_accuracy: 0.7019
# Epoch 6/10
# 782/782 [==============================] - 57s 73ms/step - loss: 0.8100 - accuracy: 0.7190 - val_loss: 0.9482 - val_accuracy: 0.6744
# Epoch 7/10
# ...

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
train_labels, test_labels = to_categorical(train_labels), to_categorical(test_labels)

# Create a CNN model with different activation functions
model = models.Sequential()

# Convolutional Layer 1 with ReLU activation
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Convolutional Layer 2 with Leaky ReLU activation
model.add(layers.Conv2D(64, (3, 3), activation=tf.keras.layers.LeakyReLU(alpha=0.1)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Convolutional Layer 3 with Sigmoid activation
model.add(layers.Conv2D(128, (3, 3), activation='sigmoid'))
model.add(layers.BatchNormalization())
model.add(layers.GlobalAveragePooling2D())

# Fully connected layers with ReLU activation
model.add(layers.Dense(128, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

# Output layer with softmax activation
model.add(layers.Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_images, train_labels, epochs=10, batch_size=64, validation_data=(test_images, test_labels))

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Epoch 1/10
# 782/782 [==============================] - 57s 70ms/step - loss: 1.7303 - accuracy: 0.4071 - val_loss: 1.5019 - val_accuracy: 0.4611
# Epoch 2/10
# 782/782 [==============================] - 54s 69ms/step - loss: 1.2547 - accuracy: 0.5514 - val_loss: 1.2405 - val_accuracy: 0.5693
# Epoch 3/10
# 782/782 [==============================] - 53s 68ms/step - loss: 1.1168 - accuracy: 0.6074 - val_loss: 1.0310 - val_accuracy: 0.6365
# Epoch 4/10
# 782/782 [==============================] - 55s 70ms/step - loss: 1.0260 - accuracy: 0.6395 - val_loss: 1.4226 - val_accuracy: 0.5349
# Epoch 5/10
# 782/782 [==============================] - 61s 78ms/step - loss: 0.9594 - accuracy: 0.6668 - val_loss: 1.2015 - val_accuracy: 0.6072
# Epoch 6/10
# 782/782 [==============================] - 54s 69ms/step - loss: 0.9088 - accuracy: 0.6835 - val_loss: 0.9744 - val_accuracy: 0.6646
# Epoch 7/10
# ...

# %%
# Define a list of optimizers to experiment with
optimizers = ['sgd', 'rmsprop']

for optimizer in optimizers:
    print(f"Training with optimizer: {optimizer}")

    # Create a CNN model
    model = models.Sequential()

    # Convolutional Layer 1
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.25))

    # Convolutional Layer 2
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.25))

    # Flatten the output for fully connected layers
    model.add(layers.Flatten())

    # Fully connected layers
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))

    # Output layer
    model.add(layers.Dense(10, activation='softmax'))

    # Compile the model with the selected optimizer
    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Train the model
    history = model.fit(train_images, train_labels, epochs=20, batch_size=64, validation_data=(test_images, test_labels))

    # Evaluate the model on test data
    test_loss, test_accuracy = model.evaluate(test_images, test_labels)
    print(f'Test accuracy with {optimizer}: {test_accuracy * 100:.2f}%')
    print("\n")
# Out:
# Training with optimizer: sgd
# Epoch 1/20
# 782/782 [==============================] - 49s 61ms/step - loss: 2.0171 - accuracy: 0.3340 - val_loss: 1.5369 - val_accuracy: 0.4557
# Epoch 2/20
# 782/782 [==============================] - 48s 61ms/step - loss: 1.5527 - accuracy: 0.4395 - val_loss: 1.5590 - val_accuracy: 0.4259
# Epoch 3/20
# 782/782 [==============================] - 48s 61ms/step - loss: 1.4376 - accuracy: 0.4812 - val_loss: 1.4019 - val_accuracy: 0.5045
# Epoch 4/20
# 782/782 [==============================] - 48s 61ms/step - loss: 1.3739 - accuracy: 0.5073 - val_loss: 1.3802 - val_accuracy: 0.4959
# Epoch 5/20
# 782/782 [==============================] - 48s 61ms/step - loss: 1.3259 - accuracy: 0.5271 - val_loss: 1.4993 - val_accuracy: 0.4670
# Epoch 6/20
# 782/782 [==============================] - 47s 61ms/step - loss: 1.2840 - accuracy: 0.5407 - val_loss: 1.3938 - val_accuracy: 0.5012
# Epoch 7/20
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

# Load and preprocess the CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
train_labels, test_labels = to_categorical(train_labels), to_categorical(test_labels)

# Define the class names (replace with your own if necessary)
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Create and train a CNN model (you can use a pre-trained model or the one you've trained)

# Assuming you have trained the model and stored it in the 'model' variable

# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_accuracy * 100:.2f}%')

# Make predictions on the test data
y_pred = model.predict(test_images)
y_true = np.argmax(test_labels, axis=1)
y_pred = np.argmax(y_pred, axis=1)

# Calculate accuracy using sklearn's accuracy_score
accuracy = accuracy_score(y_true, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')

# Generate a classification report
class_report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:")
print(class_report)

# Calculate and display the confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.get_cmap('Blues'))
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names, rotation=45)
plt.yticks(tick_marks, class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.9863 - accuracy: 0.6607
# Test accuracy: 66.07%
# 313/313 [==============================] - 3s 8ms/step
# Accuracy: 66.07%
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.92      0.43      0.59      1000
#   automobile       0.96      0.65      0.77      1000
#         bird       0.65      0.50      0.56      1000
#          cat       0.58      0.41      0.48      1000
#         deer       0.42      0.85      0.56      1000
#          dog       0.71      0.54      0.61      1000
#         frog       0.58      0.92      0.71      1000
#        horse       0.89      0.60      0.71      1000
#         ship       0.69      0.91      0.79      1000
#        truck       0.77      0.82      0.79      1000
#
#     accuracy                           0.66     10000
#    macro avg       0.72      0.66      0.66     10000
# ...
